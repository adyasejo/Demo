-- %%
%run "./School-Setup"

-- %%
%python
files = dbutils.fs.ls(f"{dataset_school}/enrollments-json-raw")
display(files)

-- %%
%python
(spark.readStream
           .format("cloudFiles")
           .option("cloudFiles.format", "json")
           .option("cloudFiles.inferColumnTypes","true")
           .option("cloudFiles.schemaLocation", "dbfs:/Workspace/Shared/DEA/checkpoints/enrollments")
           .load(f"{dataset_school}/enrollments-json-raw")
     .writeStream
           .trigger(availableNow=True)
           .option("checkpointLocation", "dbfs:/Workspace/Shared/DEA/checkpoints/enrollments")
           .table("enrollments_updates")
)

-- %%
%python
files = dbutils.fs.ls('dbfs:/Workspace/Shared/DEA/')
display(files)

-- %%
%sql
SELECT * FROM enrollments_updates

-- %%
%python
load_new_data()

-- %%
%sql
DESCRIBE HISTORY enrollments_updates

-- %%
%sql
DROP TABLE enrollments_updates

-- %%
%python
dbutils.fs.rm("dbfs:/Workspace/Shared/DEA/checkpoints/enrollments", True)
